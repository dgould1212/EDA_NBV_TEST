# %% [markdown]
# ## In this assignment you will explore the impact of several variables on laptop prices.

# %% [markdown]
# ### 1. Import the required libraries and the CSV file, 'laptops_clean.csv'.

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

laptops = pd.read_csv('laptops_clean.csv')
laptops
# Out:
#     Manufacturer     Screen  Screen_Size_inch  CPU_frequency  RAM_GB  \
# 0           Acer  IPS Panel            35.560            1.6       8
# 1           Dell    Full HD            39.624            2.0       4
# 2           Dell    Full HD            39.624            2.7       8
# 3           Dell  IPS Panel            33.782            1.6       8
# 4             HP    Full HD            39.624            1.8       8
# ..           ...        ...               ...            ...     ...
# 233       Lenovo  IPS Panel            35.560            2.6       8
# 234      Toshiba    Full HD            33.782            2.4       8
# 235       Lenovo  IPS Panel            30.480            2.6       8
# 236       Lenovo    Full HD            39.624            2.5       6
# 237      Toshiba    Full HD            35.560            2.3       8
#
#      Storage_GB_SSD  Weight_kg  Price
# 0               256       1.60    978
# 1               256       2.20    634
# ...

# %% [markdown]
# ### 2. Get a sense of your data.

# %% [markdown]
# #### Generate the summary statistics of all features in this dataset.

# %%
laptops.describe()
# Out:
#        Screen_Size_inch  CPU_frequency      RAM_GB  Storage_GB_SSD  \
# count        238.000000     238.000000  238.000000      238.000000
# mean          37.269615       2.360084    7.882353      245.781513
# std            2.946184       0.411393    2.482603       34.765316
# min           30.480000       1.200000    4.000000      128.000000
# 25%           35.560000       2.000000    8.000000      256.000000
# 50%           38.100000       2.500000    8.000000      256.000000
# 75%           39.624000       2.700000    8.000000      256.000000
# max           43.942000       2.900000   16.000000      256.000000
#
#         Weight_kg        Price
# count  238.000000   238.000000
# mean     1.862232  1462.344538
# std      0.489090   574.607699
# min      0.810000   527.000000
# 25%      1.472500  1066.500000
# 50%      1.862232  1333.000000
# 75%      2.200000  1777.000000
# max      3.600000  3810.000000

# %%
laptops.describe(include=object)
# Out:
#        Manufacturer   Screen
# count           238      238
# unique           11        2
# top            Dell  Full HD
# freq             71      161

# %% [markdown]
# #### Check the distribution of the variables. For all continuous numeric variables, create box plots. For all categorical and/or discrete numerical variables, create bar charts.

# %%
laptops['Weight_kg'].plot.box()
# Out:
# <Axes: >

# %%
laptops['CPU_frequency'].plot.box()
# Out:
# <Axes: >

# %%
laptops['Screen_Size_inch'].plot.box()
# Out:
# <Axes: >

# %%
sns.countplot(data=laptops, x='Manufacturer')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=laptops, x='Screen')
# Out:
# <Axes: xlabel='Screen', ylabel='count'>

# %%
sns.countplot(data=laptops, x='RAM_GB')
# Out:
# <Axes: xlabel='RAM_GB', ylabel='count'>

# %%
sns.countplot(data=laptops, x='Storage_GB_SSD')
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='count'>

# %% [markdown]
# #### Does there appear to be any outliers in this data and/or are their any characteristics of laptops that appear to be either overrepresented or underrepresented?

# %% [markdown]
# ### 3. Check for potential relationships between continuous numerical features and price.

# %% [markdown]
# #### Create scatter plots of each continous numerical variable vs. price, and calculate the corresponding correlation coefficients and P-values.

# %%
laptops.plot.scatter(x='Weight_kg', y='Price')
# Out:
# <Axes: xlabel='Weight_kg', ylabel='Price'>

# %%
cor_w, p_val_w = pearsonr(laptops['Weight_kg'], laptops['Price'])
cor_w, p_val_w
# Out:
# (-0.05031225837751542, 0.4397693853433896)

# %%
laptops.plot.scatter(x='CPU_frequency', y='Price')
# Out:
# <Axes: xlabel='CPU_frequency', ylabel='Price'>

# %%
cor_cpu, p_val_cpu = pearsonr(laptops['CPU_frequency'], laptops['Price'])
cor_cpu, p_val_cpu
# Out:
# (0.3666655589258864, 5.502463350713164e-09)

# %%
laptops.plot.scatter(x='Screen_Size_inch', y='Price')
# Out:
# <Axes: xlabel='Screen_Size_inch', ylabel='Price'>

# %%
cor_s, p_val_s = pearsonr(laptops['Screen_Size_inch'], laptops['Price'])
cor_s, p_val_s
# Out:
# (-0.12667154585920093, 0.05096503856873892)

# %% [markdown]
# ### 4. Check for potential relationships between categorical features and price.

# %% [markdown]
# #### Create box plots of price broken down by each categorical variable to see if any categorical characteristics appear to have an impact on the price.

# %%
sns.boxplot(data=laptops, x='Manufacturer', y='Price')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=laptops, x='Screen', y='Price')
# Out:
# <Axes: xlabel='Screen', ylabel='Price'>

# %%
sns.boxplot(data=laptops, x='RAM_GB', y='Price')
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
sns.boxplot(data=laptops, x='Storage_GB_SSD', y='Price')
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %% [markdown]
# ### 5. Conclusion

# %% [markdown]
# #### After reviewing the results of this analysis, which factors do you feel have a notable influence on the price of laptops?
